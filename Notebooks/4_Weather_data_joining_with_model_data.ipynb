# %% [markdown]
# <a href="https://colab.research.google.com/github/nilesh3030/Stroke-Prediction/blob/main/Notebooks/4_Weather_data_joining_with_model_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2024.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.25.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 57.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.8.1 fastparquet-2024.2.0

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import dateutil.parser

pd.set_option ('display.max_columns', None)
pd.set_option ('display.max_rows', None)

raw_data = pd.read_csv('/content/drive/MyDrive/Stroke_Prediction/Data/stroke_case.csv', low_memory = False)
raw_data_2021 = pd.read_csv('/content/drive/MyDrive/Stroke_Prediction/Data/stroke_data/stroke_case_2021.csv', low_memory = False)

model_data = pd.read_csv('/content/drive/MyDrive/Stroke_Prediction/Data/Modelling Data/model_data_2021_2022.csv', low_memory = False)

unique_patient_address = pd.read_csv('/content/drive/MyDrive/Stroke_Prediction/Data/unique_address_with_location.csv', encoding = 'euc_kr')
unique_patient_address_2021 = pd.read_csv('/content/drive/MyDrive/Stroke_Prediction/Data/unique_address_with_location_2021.csv', encoding = 'euc_kr')
weather_data = pd.read_parquet('/content/drive/MyDrive/Stroke_Prediction/Data/Weather_Data/weather_data_2021_22_cleaned.parquet', engine = 'fastparquet')

# %%
unique_station = weather_data.groupby(['Branch_name']).size().reset_index(name='Freq')

unique_station.shape
# Out:
# (529, 2)

# %%
unique_patient_address_2021.shape, unique_patient_address.shape
# Out:
# ((4505, 9), (2666, 9))

# %%
frames = [unique_patient_address, unique_patient_address_2021]

unique_address = pd.concat(frames)
print(unique_address.shape)
print(unique_patient_address.shape[0] + unique_patient_address_2021.shape[0])
# Out:
# (7171, 9)
# 7171

# %%
unique_address.head()
# Out:
#    Unnamed: 0        Address  Address2 Address3 Address4  Freq  \
# 0           0  강원도, 강릉시, 강동면  강원도, 강릉시      강릉시      강원도     1
# 1           1  강원도, 강릉시, 견소동  강원도, 강릉시      강릉시      강원도     1
# 2           2   강원도, 강릉시, 교동  강원도, 강릉시      강릉시      강원도     4
# 3           3  강원도, 강릉시, 내곡동  강원도, 강릉시      강릉시      강원도     1
# 4           4  강원도, 강릉시, 노암동  강원도, 강릉시      강릉시      강원도     6
#
#                                   Location   latitude   longitude
# 0                (37.7525313, 128.8759523)  37.752531  128.875952
# 1                    (37.77614, 128.93031)  37.776140  128.930310
# 2  (37.770061749999996, 128.8885009313695)  37.770062  128.888501
# 3                (37.7384314, 128.8757664)  37.738431  128.875766
# 4                    (37.74274, 128.91168)  37.742740  128.911680

# %%
# Dedup the data to handle the repeating values on branch datetime level
unique_address = unique_address.drop(['Unnamed: 0'], axis = 1)
unique_address = unique_address.drop_duplicates(subset=['Address'])

unique_address.shape
# Out:
# (4567, 8)

# %% [markdown]
# # Adding the location of weather station and assigning the weather station which is nearest from the patient's location

# %%
weather_station_location = pd.read_excel('/content/drive/MyDrive/Stroke_Prediction/Data/Meterological_branch_and_Location.xlsx')
weather_station_location.head()
# Out:
#   Branch Name  Latitude  Longitude
# 0         가거도   34.0728   125.1264
# 1          가곡   36.1250   127.6924
# 2          가덕   36.5461   127.5240
# 3         가덕도   34.9931   128.8314
# 4          가산   36.0956   128.5440

# %%
## Stripping the whitespace so that join can be done easily
weather_station_location['Branch Name'] = weather_station_location['Branch Name'].str.strip()
unique_station['Branch_name'] = unique_station['Branch_name'].str.strip()

# %%
## Attaching the location info to unique stations
unique_station_location = pd.merge(unique_station, weather_station_location,  how='inner', left_on=['Branch_name'], right_on = ['Branch Name'])

# %%
#Shape should be same as that ensures that we have location info for all the unique weather station
unique_station_location.shape
# Out:
# (529, 5)

# %%
unique_station_location = unique_station_location[['Branch Name', 'Latitude', 'Longitude']]
unique_station_location.head()
# Out:
#   Branch Name  Latitude  Longitude
# 0         가거도   34.0728   125.1264
# 1          가곡   36.1250   127.6924
# 2          가덕   36.5461   127.5240
# 3         가덕도   34.9931   128.8314
# 4          가산   36.0956   128.5440

# %%
### Attaching the branch which is nearest from the patient's location
import numpy as np
from scipy.spatial.distance import cdist

unique_address["Branch Name"] = pd.Series([unique_station_location["Branch Name"].iloc[np.argmin(x)] for x in cdist(unique_address[["latitude", "longitude"]], unique_station_location[["Latitude", "Longitude"]])])

# %%
unique_address.head()
# Out:
#          Address  Address2 Address3 Address4  Freq  \
# 0  강원도, 강릉시, 강동면  강원도, 강릉시      강릉시      강원도     1
# 1  강원도, 강릉시, 견소동  강원도, 강릉시      강릉시      강원도     1
# 2   강원도, 강릉시, 교동  강원도, 강릉시      강릉시      강원도     4
# 3  강원도, 강릉시, 내곡동  강원도, 강릉시      강릉시      강원도     1
# 4  강원도, 강릉시, 노암동  강원도, 강릉시      강릉시      강원도     6
#
#                                   Location   latitude   longitude Branch Name
# 0                (37.7525313, 128.8759523)  37.752531  128.875952          강문
# 1                    (37.77614, 128.93031)  37.776140  128.930310          강문
# 2  (37.770061749999996, 128.8885009313695)  37.770062  128.888501          강문
# 3                (37.7384314, 128.8757664)  37.738431  128.875766          강문
# 4                    (37.74274, 128.91168)  37.742740  128.911680          강문

# %%
## We will create the data on 'id' level where we map the nearest branch info for each ids
id_level_data_2022 = raw_data[['jaenan_sn', 'address_si', 'address_gu', 'address_dong', 'call_d', 'call_t']]
id_level_data_2022['Address'] = id_level_data_2022['address_si'] + ", " + id_level_data_2022['address_gu'] + ", " +  id_level_data_2022['address_dong']

id_level_data_2021 = raw_data_2021[['jaenan_sn', 'address_si', 'address_gu', 'address_dong', 'call_d', 'call_t']]
id_level_data_2021['Address'] = id_level_data_2021['address_si'] + ", " + id_level_data_2021['address_gu'] + ", " +  id_level_data_2021['address_dong']

dfs = [id_level_data_2021, id_level_data_2022]
id_level_data = pd.concat(dfs)

print(id_level_data.shape, id_level_data_2021.shape, id_level_data_2022.shape)
# Out:
# (123152, 7) (113155, 7) (9997, 7)
# <ipython-input-16-e2889129a418>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_level_data_2022['Address'] = id_level_data_2022['address_si'] + ", " + id_level_data_2022['address_gu'] + ", " +  id_level_data_2022['address_dong']
# <ipython-input-16-e2889129a418>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_level_data_2021['Address'] = id_level_data_2021['address_si'] + ", " + id_level_data_2021['address_gu'] + ", " +  id_level_data_2021['address_dong']

# %%
### Dedup the data at id level
id_level_data = id_level_data.drop_duplicates(subset=['jaenan_sn'])

# %%
null_variables = round((id_level_data.isna().sum()/len(id_level_data))*100,2)
null_variables
# Out:
# jaenan_sn       0.00
# address_si      8.77
# address_gu      8.84
# address_dong    8.77
# call_d          0.01
# call_t          0.01
# Address         8.84
# dtype: float64

# %%
(123152*(100-8.84))/100
# Out:
# 112265.3632

# %%
nearest_branch_super = id_level_data.merge(unique_address, on = 'Address')
print(nearest_branch_super.shape)
# Out:
# (112212, 15)

# %% [markdown]
# #Processing the Nearest Branch data

# %%
print(nearest_branch_super.shape)
nearest_branch_super.head()
# Out:
# (112212, 15)
#       jaenan_sn address_si address_gu address_dong    call_d call_t  \
# 0  VO1137306005      서울특별시         중구          예장동  20210123   1629
# 1  VW1138663575      서울특별시         중구          예장동  20210915   1838
# 2  VO1137314160      서울특별시         중구          예장동  20210125   1427
# 3  VU1138288888      서울특별시         중구          예장동  20210723   1430
# 4  VR1137694704      서울특별시         중구          예장동  20210419    917
#
#           Address   Address2 Address3 Address4  Freq               Location  \
# 0  서울특별시, 중구, 예장동  서울특별시, 중구       중구    서울특별시     1  (37.55492, 126.98941)
# 1  서울특별시, 중구, 예장동  서울특별시, 중구       중구    서울특별시     1  (37.55492, 126.98941)
# 2  서울특별시, 중구, 예장동  서울특별시, 중구       중구    서울특별시     1  (37.55492, 126.98941)
# 3  서울특별시, 중구, 예장동  서울특별시, 중구       중구    서울특별시     1  (37.55492, 126.98941)
# 4  서울특별시, 중구, 예장동  서울특별시, 중구       중구    서울특별시     1  (37.55492, 126.98941)
#
#    latitude  longitude Branch Name
# 0  37.55492  126.98941          중구
# 1  37.55492  126.98941          중구
# 2  37.55492  126.98941          중구
# 3  37.55492  126.98941          중구
# 4  37.55492  126.98941          중구

# %%
nearest_branch_super.columns
# Out:
# Index(['jaenan_sn', 'address_si', 'address_gu', 'address_dong', 'call_d',
#        'call_t', 'Address', 'Address2', 'Address3', 'Address4', 'Freq',
#        'Location', 'latitude', 'longitude', 'Branch Name'],
#       dtype='object')

# %%
vars = ['jaenan_sn','call_d', 'call_t', 'latitude', 'longitude', 'Branch Name']
nearest_branch = nearest_branch_super[vars]
#rename the branch name to weather station######
#'latitude', 'longitude' are the locations for the address i.e. patient location
# 'Latitude', 'Longitude' are location respective to branch address

# %%
convert_dict = {'call_d': str,
                'call_t': str}

nearest_branch = nearest_branch.astype(convert_dict)

nearest_branch["Datetime_patient"] = nearest_branch["call_d"] + nearest_branch["call_t"]

# %%
def convert_datetime(row):
  try:
    if len(row['Datetime_patient']) == 11 or len(row['Datetime_patient']) == 12:
      return(pd.to_datetime(row['Datetime_patient'], format = '%Y%m%d%H%M'))
  except:
    return(np.nan)


nearest_branch['Datetime_converted'] = nearest_branch.apply(lambda row: convert_datetime(row), axis=1)

# %%
nearest_branch['Datetime_converted'] = nearest_branch['Datetime_converted'].dt.strftime('%Y-%m-%d %H')

# %%
print(nearest_branch.shape)
nearest_branch.head()
# Out:
# (112212, 8)
#       jaenan_sn    call_d call_t  latitude  longitude Branch Name  \
# 0  VO1137306005  20210123   1629  37.55492  126.98941          중구
# 1  VW1138663575  20210915   1838  37.55492  126.98941          중구
# 2  VO1137314160  20210125   1427  37.55492  126.98941          중구
# 3  VU1138288888  20210723   1430  37.55492  126.98941          중구
# 4  VR1137694704  20210419    917  37.55492  126.98941          중구
#
#   Datetime_patient Datetime_converted
# 0     202101231629      2021-01-23 16
# 1     202109151838      2021-09-15 18
# 2     202101251427      2021-01-25 14
# 3     202107231430      2021-07-23 14
# 4      20210419917      2021-04-19 09

# %% [markdown]
# #Combining weather and nearest-branch data

# %%
new_df = pd.merge(nearest_branch, weather_data,  how='left', left_on=['Branch Name','Datetime_converted'], right_on = ['Branch_name','Date_time'])
print(new_df.shape)
new_df.head()
# Out:
# (112212, 43)
#       jaenan_sn    call_d call_t  latitude  longitude Branch Name  \
# 0  VO1137306005  20210123   1629  37.55492  126.98941          중구
# 1  VW1138663575  20210915   1838  37.55492  126.98941          중구
# 2  VO1137314160  20210125   1427  37.55492  126.98941          중구
# 3  VU1138288888  20210723   1430  37.55492  126.98941          중구
# 4  VR1137694704  20210419    917  37.55492  126.98941          중구
#
#   Datetime_patient Datetime_converted  Branch_code Branch_name      Date_time  \
# 0     202101231629      2021-01-23 16        419.0          중구  2021-01-23 16
# 1     202109151838      2021-09-15 18        419.0          중구  2021-09-15 18
# 2     202101251427      2021-01-25 14        419.0          중구  2021-01-25 14
# 3     202107231430      2021-07-23 14        419.0          중구  2021-07-23 14
# 4      20210419917      2021-04-19 09        419.0          중구  2021-04-19 09
#
#    Temperature  Wind_Speed(m/s)  Precipitation(mm)  Humidity(%)    Year  \
# 0          9.2              3.5                0.0          NaN  2021.0
# 1         23.2              4.5                0.0         51.1  2021.0
# 2          9.0              2.3                0.0          NaN  2021.0
# 3         32.9              2.1                0.0         45.2  2021.0
# 4         12.2              0.6                0.0          NaN  2021.0
#
#    Month       Date  Hour  Temp_max_month  Temp_min_month  Temp_avg_month  \
# 0    1.0 2021-01-23  16.0            11.0           -19.9       -3.444953
# 1    9.0 2021-09-15  18.0            29.1            15.3       20.998889
# 2    1.0 2021-01-25  14.0            11.0           -19.9       -3.444953
# 3    7.0 2021-07-23  14.0            35.5            18.5       27.035646
# 4    4.0 2021-04-19   9.0            28.0             2.5       13.216875
#
#    Humidity_max_month  Humidity_min_month  Humidity_avg_month  \
# 0                97.8                19.0           52.504435
# 1                99.6                36.7           71.832500
# 2                97.8                19.0           52.504435
# 3                97.6                37.4           61.983710
# 4                98.5                14.6           53.383333
#
#    diff_Temp_max_month  diff_Temp_min_month  diff_Temp_avg_month  \
# 0                  NaN                  NaN                  NaN
# 1                 -3.7                 -1.0            -3.336864
# 2                  NaN                  NaN                  NaN
# 3                  3.4                  6.3             5.380438
# 4                  5.8                  5.4             5.962305
#
#    diff_Humidity_max_month  diff_Humidity_min_month  diff_Humidity_avg_month  \
# 0                      NaN                      NaN                      NaN
# 1                      0.4                     -5.5                -3.833898
# 2                      NaN                      NaN                      NaN
# 3                     -1.8                     20.2               -13.236290
# 4                     -0.6                      1.8                -6.701344
#
#    Temp_max_day  Temp_min_day  Temp_avg_day  Humidity_max_day  \
# 0           9.2           3.7      5.712500               NaN
# 1          25.3          19.4     21.700000              67.3
# 2          11.0           2.9      7.141667               NaN
# 3          33.9          25.8     29.762500              73.5
# 4          19.6           5.6     11.925000               NaN
#
#    Humidity_min_day  Humidity_avg_day  diff_Temp_max_day  diff_Temp_min_day  \
# 0               NaN               NaN                3.8                0.3
# 1              46.0         57.758333               -0.9                0.2
# 2               NaN               NaN                0.1                0.8
# 3              43.3         59.345833                2.3                0.0
# 4               NaN               NaN                4.6                1.2
#
#    diff_Temp_avg_day  diff_Humidity_max_day  diff_Humidity_min_day  \
# 0           1.737500                    NaN                    NaN
# 1          -1.079167                  -19.0                   -0.1
# 2           1.058333                    NaN                    NaN
# 3           1.422500                   12.9                   -4.2
# 4           2.950000                    NaN                    NaN
#
#    diff_Humidity_avg_day
# 0                    NaN
# 1              -6.512500
# 2                    NaN
# 3               4.125833
# 4                    NaN

# %%
null_variables = round((new_df.isna().sum()/len(new_df))*100,2)
null_variables
# Out:
# jaenan_sn                   0.00
# call_d                      0.00
# call_t                      0.00
# latitude                    0.00
# longitude                   0.00
# Branch Name                 0.00
# Datetime_patient            0.00
# Datetime_converted          4.30
# Branch_code                 6.14
# Branch_name                 6.14
# Date_time                   6.14
# Temperature                 6.32
# Wind_Speed(m/s)             6.48
# Precipitation(mm)           7.08
# Humidity(%)                20.28
# Year                        6.14
# Month                       6.14
# Date                        6.14
# Hour                        6.14
# Temp_max_month              6.14
# Temp_min_month              6.14
# Temp_avg_month              6.14
# Humidity_max_month         14.03
# Humidity_min_month         14.03
# Humidity_avg_month         14.03
# diff_Temp_max_month        12.84
# diff_Temp_min_month        12.84
# diff_Temp_avg_month        12.84
# diff_Humidity_max_month    20.57
# diff_Humidity_min_month    20.57
# diff_Humidity_avg_month    20.57
# Temp_max_day                6.16
# Temp_min_day                6.16
# Temp_avg_day                6.16
# Humidity_max_day           20.14
# Humidity_min_day           20.14
# Humidity_avg_day           20.14
# diff_Temp_max_day           6.35
# diff_Temp_min_day           6.35
# diff_Temp_avg_day           6.35
# diff_Humidity_max_day      20.35
# diff_Humidity_min_day      20.35
# diff_Humidity_avg_day      20.35
# dtype: float64

# %%
clean_data_with_weather_variables = new_df.copy()
clean_data_with_weather_variables.shape
# Out:
# (112212, 43)

# %% [markdown]
# # Joining the model data with the cleaned weather data

# %%
final_data = pd.merge(model_data, clean_data_with_weather_variables,  how='inner', on = 'jaenan_sn')
print(final_data.shape)
final_data.head()
# Out:
# (99723, 76)
#                     cv_cc                cv2_cc        cv2_act  sex  stroke  \
# 0             Cerebralgia         Consciousness  Everyday life    0       0
# 1             Cerebralgia         Consciousness  Everyday life    0       0
# 2             Cerebralgia  Upper body Paralysis        on duty    0       0
# 3  Heart, cerebrovascular                 Faint  Everyday life    1       0
# 4             Cerebralgia  Upper body Paralysis    After sleep    1       0
#
#    cv2_cphss              triage  onset     jaenan_sn   age   dbp1   sbp1  \
# 0        1.0  Emergency symptoms      0  VO1137306005  76.0   81.0  117.0
# 1        1.0  Emergency symptoms      0  VP1137357129  78.0   70.0  120.0
# 2        1.0  Emergency symptoms      0  VP1137373420  50.0  118.0  227.0
# 3        0.0     Quasi -negative      0  VP1137407272  74.0  100.0  180.0
# 4        1.0  Emergency symptoms      0  VP1137408976  28.0  110.0  220.0
#
#      pr1   rr1   bt1  spo2_1   dbp2   sbp2    pr2   rr2   bt2  spo2_2  \
# 0  149.0  14.0  37.1    96.0   88.0  121.0  142.0  13.0  36.9    97.0
# 1  144.0  28.0  40.0    92.0   65.0   99.0  135.0  24.0  39.5    96.0
# 2  101.0  15.0  37.7    98.0  121.0  213.0   92.0  15.0  37.6    99.0
# 3  111.0  18.0  36.3    99.0  110.0  189.0  121.0  18.0  36.6    99.0
# 4   96.0  13.0  37.2    98.0  110.0  200.0   92.0  14.0  37.0    98.0
#
#    Weekday  Month_x  Year_x  Hour_x  Minute  Spasm  Dizziness  Faint  \
# 0      5.0      1.0  2021.0    16.0    29.0      0          0      0
# 1      3.0      2.0  2021.0    14.0    51.0      0          0      0
# 2      0.0      2.0  2021.0    11.0    53.0      0          0      0
# 3      0.0      2.0  2021.0     5.0    30.0      0          0      1
# 4      0.0      2.0  2021.0    14.0    18.0      0          0      0
#
#    Consciousness  Paralysis  hy_di_disease  Disease_counts    call_d call_t  \
# 0              1          0              0               0  20210123   1629
# 1              1          0              1               3  20210204   1451
# 2              0          1              1               1  20210208   1153
# 3              0          0              1               2  20210215    530
# 4              0          1              1               1  20210215   1418
#
#     latitude   longitude Branch Name Datetime_patient Datetime_converted  \
# 0  37.554920  126.989410          중구     202101231629      2021-01-23 16
# 1  37.550353  126.981563          중구     202102041451      2021-02-04 14
# 2  37.671229  126.761800          김포     202102081153      2021-02-08 11
# 3  37.550353  126.981563          중구      20210215530      2021-02-15 05
# 4  37.366280  127.118730          성남     202102151418      2021-02-15 14
#
#    Branch_code Branch_name      Date_time  Temperature  Wind_Speed(m/s)  \
# 0        419.0          중구  2021-01-23 16          9.2              3.5
# 1        419.0          중구  2021-02-04 14         -2.6              2.0
# 2        441.0          김포  2021-02-08 11         -1.9              3.9
# 3        419.0          중구  2021-02-15 05          3.3              2.3
# 4        572.0          성남  2021-02-15 14          2.6              4.2
#
#    Precipitation(mm)  Humidity(%)  Year_y  Month_y       Date  Hour_y  \
# 0                0.0          NaN  2021.0      1.0 2021-01-23    16.0
# 1                0.0          NaN  2021.0      2.0 2021-02-04    14.0
# 2                0.0          NaN  2021.0      2.0 2021-02-08    11.0
# 3                0.5          NaN  2021.0      2.0 2021-02-15     5.0
# 4                0.0         38.9  2021.0      2.0 2021-02-15    14.0
#
#    Temp_max_month  Temp_min_month  Temp_avg_month  Humidity_max_month  \
# 0            11.0           -19.9       -3.444953                97.8
# 1            16.6           -12.2       -0.290199                96.3
# 2            16.2            -9.7        0.387443                 NaN
# 3            16.6           -12.2       -0.290199                96.3
# 4            18.6           -10.0        0.733206                90.1
#
#    Humidity_min_month  Humidity_avg_month  diff_Temp_max_month  \
# 0                19.0           52.504435                  NaN
# 1                17.8           52.482712                  5.6
# 2                 NaN                 NaN                  3.2
# 3                17.8           52.482712                  5.6
# 4                 9.9           48.168899                  5.5
#
#    diff_Temp_min_month  diff_Temp_avg_month  diff_Humidity_max_month  \
# 0                  NaN                  NaN                      NaN
# 1                  7.7             3.154754                     -1.5
# 2                  7.8             3.055991                      NaN
# 3                  7.7             3.154754                     -1.5
# 4                  8.5             3.270798                     -1.2
#
#    diff_Humidity_min_month  diff_Humidity_avg_month  Temp_max_day  \
# 0                      NaN                      NaN           9.2
# 1                     -1.2                -0.021723          -0.3
# 2                      NaN                      NaN           0.4
# 3                     -1.2                -0.021723           7.0
# 4                     -2.2                -3.539104           7.5
#
#    Temp_min_day  Temp_avg_day  Humidity_max_day  Humidity_min_day  \
# 0           3.7      5.712500               NaN               NaN
# 1          -8.8     -4.533333               NaN               NaN
# 2          -4.9     -2.500000               NaN               NaN
# 3          -6.7      0.629167               NaN               NaN
# 4          -4.2      2.704167              82.7              31.5
#
#    Humidity_avg_day  diff_Temp_max_day  diff_Temp_min_day  diff_Temp_avg_day  \
# 0               NaN                3.8                0.3           1.737500
# 1               NaN               -0.8                1.2           0.454167
# 2               NaN               -7.0               -3.0          -6.058333
# 3               NaN               -6.5              -13.9          -8.762500
# 4         53.241667               -6.8               -7.7          -5.762500
#
#    diff_Humidity_max_day  diff_Humidity_min_day  diff_Humidity_avg_day
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                   18.9                    7.1                   7.25

# %%
final_data.columns
# Out:
# Index(['cv_cc', 'cv2_cc', 'cv2_act', 'sex', 'stroke', 'cv2_cphss', 'triage',
#        'onset', 'jaenan_sn', 'age', 'dbp1', 'sbp1', 'pr1', 'rr1', 'bt1',
#        'spo2_1', 'dbp2', 'sbp2', 'pr2', 'rr2', 'bt2', 'spo2_2', 'Weekday',
#        'Month_x', 'Year_x', 'Hour_x', 'Minute', 'Spasm', 'Dizziness', 'Faint',
#        'Consciousness', 'Paralysis', 'hy_di_disease', 'Disease_counts',
#        'call_d', 'call_t', 'latitude', 'longitude', 'Branch Name',
#        'Datetime_patient', 'Datetime_converted', 'Branch_code', 'Branch_name',
#        'Date_time', 'Temperature', 'Wind_Speed(m/s)', 'Precipitation(mm)',
#        'Humidity(%)', 'Year_y', 'Month_y', 'Date', 'Hour_y', 'Temp_max_month',
#        'Temp_min_month', 'Temp_avg_month', 'Humidity_max_month',
#        'Humidity_min_month', 'Humidity_avg_month', 'diff_Temp_max_month',
#        'diff_Temp_min_month', 'diff_Temp_avg_month', 'diff_Humidity_max_month',
#        'diff_Humidity_min_month', 'diff_Humidity_avg_month', 'Temp_max_day',
#        'Temp_min_day', 'Temp_avg_day', 'Humidity_max_day', 'Humidity_min_day',
#        'Humidity_avg_day', 'diff_Temp_max_day', 'diff_Temp_min_day',
#        'diff_Temp_avg_day', 'diff_Humidity_max_day', 'diff_Humidity_min_day',
#        'diff_Humidity_avg_day'],
#       dtype='object')

# %%
### There are many columns related with datetime and weather stations that would not be relevant for modelling so we will drop them
### keeping the month and year information to check the distribution of the final model data
vars_to_remove = ['Weekday','Hour_x','Minute','call_d','call_t','latitude','longitude','Branch Name','Datetime_patient','Datetime_converted',
'Branch_code','Date_time','Year_y','Month_y','Date','Hour_y']

final_data = final_data.drop(vars_to_remove, axis = 1)
final_data.shape
# Out:
# (99723, 60)

# %%
final_data.to_csv('/content/drive/MyDrive/Stroke_Prediction/Data/Modelling Data/model_data_2021_2022_with_weather_vars.csv')
